# %% [markdown]
# # Plot the individual contributions of different molecules
#
# Tom Schad | 27 July 2023

# %%
import numpy as np 
import matplotlib.pyplot as plt
import os 
import glob
import sys
from py4cats import *  

import matplotlib.pyplot as plt
# %matplotlib widget 
plt.rcParams.update({'figure.max_open_warning': 0})
plt.rcParams["image.origin"] = 'lower'
plt.rcParams["image.cmap"] = 'gray'
plt.rcParams["image.interpolation"] = 'nearest'
plt.rcParams['font.sans-serif'] = "Comic Sans MS"
plt.rcParams['font.family'] = "serif"
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
from scipy import ndimage

from tqdm.auto import trange
import multiprocessing

# %%
#3928 to 3942

# %%
def vac2air(wave_vac):
    """ Converts wavelengths from vacuum to air-equivalent """
    wave_air = np.copy(wave_vac)
    ww  = (wave_vac >= 2000) 
    sigma2 = (1e4 / wave_vac[ww])**2 
    n = 1 + 0.0000834254 + 0.02406147 / (130 - sigma2) + 0.00015998 / (38.9 - sigma2)
    wave_air[ww] = wave_vac[ww] / n
    return wave_air

# %%
def air2vac(wave_air): 
    """ Converts wavelengths from air-equivalent to vacuum
    Ciddor (1996) formula
    Adapted from airtovac.pro
    
    wave_air  :: angstroms 
    """
    wave_vac = np.copy(wave_air)
    ww  = (wave_air >= 2000) 
    sigma2 = (1e4 / wave_air[ww])**2 
    n = 1. + 8.336624212083e-5 + 0.02408926869968 / (130.1065924522 - sigma2) + \
        0.0001599740894897 / (38.92568793293 - sigma2)
    wave_vac[ww] = wave_air[ww] * n
    return wave_vac

# %%
## Wavenumber range of 350 to 5000 nm 
1e7/(air2vac(np.array([3500.,50000.]))/10.)
## 2546 to 2536
# Out:
# array([28563.25629993,  1999.45477389])

# %% [raw]
# lrwxrwxrwx 1 tschad dkist   18 Feb 10  2019 uss.xy -> USstandard_main.xy
# lrwxrwxrwx 1 tschad dkist   18 Feb 10  2019 saw.xy -> subarcticWinter.xy
# lrwxrwxrwx 1 tschad dkist   18 Feb 10  2019 sas.xy -> subarcticSummer.xy
# lrwxrwxrwx 1 tschad dkist   20 Feb 10  2019 mlw.xy -> midlatitudeWinter.xy
# lrwxrwxrwx 1 tschad dkist   20 Feb 10  2019 mls.xy -> midlatitudeSummer.xy
# lrwxrwxrwx 1 tschad dkist   11 Feb 10  2019 tro.xy -> tropical.xy

# %% [markdown]
# ## Load atmospheres

# %%
atm_midLatWinter = atmRead('./py4cats/data/atmos/50/midlatitudeWinter.xy')
atm_standard = atmRead('./py4cats/data/atmos/50/USstandard_main.xy')
# Out:
#  Atmos1d: got p & T (computed air density from p/kT)   and 8 molecules on 50 levels
#  Atmos1d: got p, T, air   and 7 molecules on 50 levels

# %%
550000. # g/cm/s^2 
550000./1000.*100  # Pas
550000./1000.*100 / 101325 # atm
# Out:
# 0.5428077966938071

# %%
## z, pressure in atm, temp
for n in range(10): 
    print(n,' ',atm_midLatWinter['z'][n]/1e5,atm_midLatWinter['p'][n]/1000.*100./101325.,atm_midLatWinter['T'][n])
# Out:
# 0   0.0 1.004687885516901 272.2
# 1   1.0 0.8855662472242783 268.7
# 2   2.0 0.7793733037256353 265.2
# 3   3.0 0.6847273624475697 261.7
# 4   4.0 0.6001480384900074 255.7
# 5   5.0 0.5243523316062175 249.7
# 6   6.0 0.4566493955094991 243.7
# 7   7.0 0.39634838391315075 237.7
# 8   8.0 0.34275845053047127 231.7
# 9   9.0 0.29538613372810263 225.7

# %%
plt.figure()
plt.plot(atm_midLatWinter['z']/1e5,atm_midLatWinter['p']/1000.*100./101325.)
plt.ylabel("P [atm]")
plt.xlabel("Height [km]")
# Out:
# Text(0.5, 0, 'Height [km]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,ax = plt.subplots(2,4,figsize = (10,6),sharey=True)
ax = ax.flatten()
plt.sca(ax[0])
atmPlot(atm_midLatWinter,label = 'midLatWinter')
atmPlot(atm_standard,label = 'Standard')
ax[0].legend()

main_mol = 'H2O','CO2','O3','N2O','CO','CH4','O2',
for n in range(1,8): 
    plt.sca(ax[n])
    atmPlot(atm_midLatWinter,main_mol[n-1],label = 'midLatWinter')
    atmPlot(atm_standard,main_mol[n-1],label = 'Standard')
    ax[n].set_xscale('log')
    ax[n].legend()

fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(atm_midLatWinter['H2O']/atm_standard['H2O'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,ax = plt.subplots(2,4,figsize = (10,6),sharey=True)
ax = ax.flatten()
plt.sca(ax[0])
atmPlot(atm_midLatWinter,label = 'midLatWinter')
atmPlot(atm_standard,label = 'Standard')
ax[0].legend()

main_mol = 'H2O','CO2','O3','N2O','CO','CH4','O2',
for n in range(1,8): 
    plt.sca(ax[n])
    plt.plot(vmr(atm_midLatWinter,main_mol[n-1]),atm_midLatWinter['z']/1e5,label = 'midLatWinter')
    plt.plot(vmr(atm_standard,main_mol[n-1]),atm_standard['z']/1e5,label = 'Standard')
    plt.xscale('log')
    plt.xlabel('Vol Mixing Ratio ['+main_mol[n-1] + ']')
    ax[n].legend()

fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Get vertical column densities [molec / cm**2 ]

# %%
print(f"Vertical column density in tropics (full atmosphere): {vcd(atm_midLatWinter,'H2O',zMin = 0.0)}") 
print(f"Vertical column density in tropics (above 3km): {vcd(atm_midLatWinter,'H2O',zMin = 3.0)}") 
print(f"Vertical column density in US standard (full atmosphere): {vcd(atm_standard,'H2O',zMin = 0.0)}") 
print(f"Vertical column density in US standard  (above 3km): {vcd(atm_standard,'H2O',zMin = 3.0)}")
# Out:
# Vertical column density in tropics (full atmosphere): 2.8906793192152994e+22
# Vertical column density in tropics (above 3km): 6.689164304859456e+21
# Vertical column density in US standard (full atmosphere): 4.808953629516041e+22
# Vertical column density in US standard  (above 3km): 1.1474288295160396e+22

# %% [markdown]
# ###  Calculate precipitable water
# * mass density of water is ~ 0.9998 g/cm**3
# * average molar mass of water is 18.01528 g/mol
# * Na = 6.022e23

# %%
# V = rho * h * Na / M 
rho = 0.9998  # g/cm**3
Na = 6.022e23 # molec / mole 
M = 18.01528 # g / mole 
V = vcd(atm_midLatWinter,'H2O',zMin = 3.0)
h = V /rho/Na * M * 10  ## millimeters
print(h,' millimeters PWV [midLatWinter]')
V = vcd(atm_standard,'H2O',zMin = 3.0)
h = V /rho/Na * M * 10  ## millimeters
print(h,' millimeters PWV [standard]')
# Out:
# 2.001515678726055  millimeters PWV [midLatWinter]
# 3.4333089872381177  millimeters PWV [standard]

# %%
print(' Column Mixing Ratios: ')
for mol in main_mol: 
    print(mol,': ',cmr(atm_standard,mol),' ',cmr(atm_midLatWinter,mol))
# Out:
#  Column Mixing Ratios:
# H2O :  0.002229410417070704   0.0013339356157016577
# CO2 :  0.0003299997842732906   0.00032999976609065525
# O3 :  4.3066488345722325e-07   4.7050180472127663e-07
# N2O :  3.069927242334716e-07   2.985580417295545e-07
# CO :  1.1090503302790937e-07   1.1193728422709478e-07
# CH4 :  1.6475201901221172e-06   1.5905201894530973e-06
# O2 :  0.20899988385262291   0.2089998775533233

# %% [markdown]
# ## 1st run example

# %%
wv0,wv1 = 8540,8550
wv0,wv1 = 10825,10845
wv0,wv1 = 5890,5900

wn1,wn0 = 1e7/(air2vac(np.array([wv0,wv1]))/10.)
print(wv0,wv1)
print(wn1,wn0)

dictOfLineLists = higstract('./HITRAN_VIS_IR/65e912c9.par',(wn0,wn1),molecule = 'main',verbose = False)
print(dictOfLineLists.keys())

## limit the lines to those of some minimum strength
strMin = 1e-28
keys = dictOfLineLists.keys()
keys = [key for key in keys]
cnt =0
for mol in keys: 
    wg = dictOfLineLists[mol]['S'] >= strMin
    dictOfLineLists[mol] = dictOfLineLists[mol][wg]
    cnt += len(dictOfLineLists[mol])
    if len(dictOfLineLists[mol]) == 0: 
        dictOfLineLists.pop(mol, None)
print(' number of lines:',cnt)


atm_standard = atmRead('./py4cats/data/atmos/50/USstandard_main.xy',zBoA  = 3) ################## 3 KILOMETERS FOR HALEAKALA - DKIST 
V = vcd(atm_standard,'H2O')
h = V /rho/Na * M * 10  ## millimeters
pwv_standard = h 
print(h,' millimeters PWV [standard]')

## get absorption cross sections
xssDict = lbl2xs(dictOfLineLists, atm_standard['p'], atm_standard['T'],(wn0,wn1),verbose = False)

plt.figure()

## loop over ppwv and airmass 
for ppwv in (1,2,3,4,5,6,8,10,):
    
    ## changes in precipitable water 
    atm_standard = atmRead('./py4cats/data/atmos/50/USstandard_main.xy',zBoA  = 3)
    atm_standard['H2O'] *= ppwv / pwv_standard
    V = vcd(atm_standard,'H2O')

    ## absorption coefficients
    absCoList = xs2ac(atm_standard, xssDict) 
    ## Optical depth
    dodList = ac2dod(absCoList,verbose=False)

    for airmass in 1,1.5,2,3:
        ## change the airmass for a slant geometry 
        for n in range(len(dodList)): 
            dodList[n] = dodList[n]*airmass  ## airmass    
        tod = dod2tod(dodList)  ## total od 

        ## back -correct the list to reapply a scaling
        for n in range(len(dodList)): 
            dodList[n] = dodList[n]/airmass  ## airmass    
    
        plt.plot(vac2air(1e7/tod.grid()*10),np.exp(-tod),lw = 1)

        wvair = vac2air(1e7/tod.grid()*10)
# Out:
# 5890 5900
# 16975.04668137837 16946.28029147602
# # first line in spectral range at record number 1333310 found in 7036732.521248005 sec
#  b' 1216946.331342 3.000E-29 3.311E-04.08681.122  444.84620.69-.032850'
# # last  line     accepted
#  b' 1116974.978086 1.342E-29 4.306E-06.05010.281 1327.11000.39-.013717'
# # first line not accepted
#  b' 1116975.284700 1.042E-30 9.503E-07.05010.281 1524.84790.41-.013718'
#  main gases only:  deleted  0  of  1  molecules in dict of linelists with originally 634 lines
#
#  634 lines of  1  molecule(s) extracted from  ./HITRAN_VIS_IR/65e912c9.par
#  returning a dictionary of lineArray's for  H2O
# dict_keys(['H2O'])
#  number of lines: 272
#  Atmos1d: got p, T, air   and 7 molecules on 50 levels
#  WARNING --- atmTruncate:  zBoA very small, assuming kilometer units
# 3.4333089872381177  millimeters PWV [standard]
#
#  lbl2xs:  H2O       18.02amu 272 lines @ reference p [g/cm/s**2]  1.013e+06      T [K] 296.00  ---> 47 p,T pairs
#  cross section  H2O        272 lines     701.2mb  268.7K        2113      0.09sec   149.48ns:  2.71649e-26 < xs < 9.07515e-24
#  cross section  H2O        272 lines     616.6mb  262.2K        2305      0.08sec   131.13ns:  2.44924e-26 < xs < 1.02267e-23
#  cross section  H2O        272 lines     540.5mb  255.7K        2561      0.09sec   129.70ns:  2.19905e-26 < xs < 1.15972e-23
#  cross section  H2O        272 lines     472.2mb  249.2K        2753      0.08sec   113.07ns:  1.97067e-26 < xs < 1.32256e-23
#  cross section  H2O        272 lines     411.1mb  242.7K        3009      0.09sec   103.96ns:  1.75978e-26 < xs < 1.50203e-23
#  cross section  H2O        272 lines     356.5mb  236.2K        3265      0.09sec   100.93ns:  1.56577e-26 < xs < 1.70669e-23
#  cross section  H2O        272 lines       308mb  229.7K        3521      0.08sec    88.27ns:  1.38908e-26 < xs < 1.93876e-23
#  cross section  H2O        272 lines       265mb  223.3K        3841      0.09sec    82.06ns:  1.22847e-26 < xs < 2.19479e-23
#  cross section  H2O        272 lines       227mb  216.8K        4097      0.09sec    78.79ns:  1.08312e-26 < xs < 2.49098e-23
#  cross section  H2O        272 lines       194mb  216.7K        4417      0.08sec    70.32ns:  9.26606e-27 < xs < 2.75166e-23
#  cross section  H2O        272 lines     165.8mb  216.7K        4673      0.08sec    66.22ns:  7.92123e-27 < xs < 3.02416e-23
#  cross section  H2O        272 lines     141.7mb  216.7K        4929      0.09sec    64.25ns:  6.77006e-27 < xs < 3.30006e-23
#  cross section  H2O        272 lines     121.1mb  216.7K        5185      0.08sec    60.06ns:  5.7869e-27 < xs < 3.57201e-23
#  cross section  H2O        272 lines     103.5mb  216.7K        5377      0.08sec    57.93ns:  4.94631e-27 < xs < 3.84922e-23
#  cross section  H2O        272 lines      88.5mb  216.7K        5569      0.09sec    57.36ns:  4.23012e-27 < xs < 4.09953e-23
#  cross section  H2O        272 lines     75.65mb  216.7K        5697      0.09sec    54.95ns:  3.61563e-27 < xs < 4.3283e-23
#  cross section  H2O        272 lines     64.67mb  216.7K        5889      0.08sec    52.82ns:  3.09138e-27 < xs < 4.56101e-23
#    42   100.00km             7169 points    <ac> =   1.1e-18      2.33e-26 < ac <  1.02e-16  @ 16949.759708cm-1
#    43   105.00km             6913 points    <ac> =  3.86e-19      3.58e-27 < ac <  3.34e-17  @ 16949.759560cm-1
#    44   110.00km             6465 points    <ac> =  1.29e-19       5.4e-28 < ac <  9.52e-18  @ 16949.760384cm-1
#    45   115.00km             5761 points    <ac> =  4.54e-20      9.83e-29 < ac <  2.59e-18  @ 16949.761224cm-1
#    46   120.00km             5249 points    <ac> =  1.85e-20      2.43e-29 < ac <  8.68e-19  @ 16968.463519cm-1
#
#  INFO --- ac2dod: 47  abs.coefficients with altitudes increasing and pressures decreasing
#  layer #   0        3.0 --   4.0km   1.797e+24molec/cm2  --->         2305   <dod>=9.87e-04   3.692e-05 < dod <   0.01341
#  layer #   1        4.0 --   5.0km   1.617e+24molec/cm2  --->         2561   <dod>=5.99e-04   1.997e-05 < dod <  0.009091
#  layer #   2        5.0 --   6.0km   1.452e+24molec/cm2  --->         2753   <dod>=3.55e-04    1.05e-05 < dod <  0.006061
#  layer #   3        6.0 --   7.0km   1.300e+24molec/cm2  --->         3009   <dod>=2.08e-04   5.445e-06 < dod <  0.003974
#  layer #   4        7.0 --   8.0km   1.160e+24molec/cm2  --->         3265   <dod>=1.17e-04   2.716e-06 < dod <   0.00253
#  layer #   5        8.0 --   9.0km   1.032e+24molec/cm2  --->         3521   <dod>=5.97e-05   1.226e-06 < dod <  0.001429
#  layer #   6        9.0 --  10.0km   9.154e+23molec/cm2  --->         3841   <dod>=2.33e-05   4.184e-07 < dod < 0.0006218
#  layer #   7       10.0 --  11.0km   8.090e+23molec/cm2  --->         4097   <dod>=9.65e-06   1.509e-07 < dod < 0.0002914
#  layer #   8       11.0 --  12.0km   7.034e+23molec/cm2  --->         4417   <dod>=4.42e-06   5.994e-08 < dod < 0.0001484
#  layer #   9       12.0 --  13.0km   6.013e+23molec/cm2  --->         4673   <dod>=2.05e-06    2.37e-08 < dod < 7.626e-05
#  layer #  10       13.0 --  14.0km   5.139e+23molec/cm2  --->         4929   <dod>=9.84e-07   9.745e-09 < dod < 4.008e-05
#  layer #  11       14.0 --  15.0km   4.392e+23molec/cm2  --->         5185   <dod>=5.38e-07   4.478e-09 < dod < 2.402e-05
#  layer #  12       15.0 --  16.0km   3.754e+23molec/cm2  --->         5377   <dod>=3.77e-07   2.692e-09 < dod < 1.819e-05
#  layer #  13       16.0 --  17.0km   3.209e+23molec/cm2  --->         5569   <dod>=2.79e-07   1.687e-09 < dod < 1.444e-05
#  layer #  14       17.0 --  18.0km   2.743e+23molec/cm2  --->         5697   <dod>=2.35e-07   1.212e-09 < dod < 1.285e-05
#  layer #  15       18.0 --  19.0km   2.345e+23molec/cm2  --->         5889   <dod>=2.00e-07   8.852e-10 < dod < 1.163e-05
#  layer #  16       19.0 --  20.0km   2.005e+23molec/cm2  --->         6017   <dod>=1.73e-07   6.525e-10 < dod < 1.044e-05
#  layer #  17       20.0 --  21.0km   1.711e+23molec/cm2  --->         6081   <dod>=1.50e-07   4.826e-10 < dod < 9.452e-06
#  layer #  18       21.0 --  22.0km   1.457e+23molec/cm2  --->         6145   <dod>=1.30e-07   3.577e-10 < dod < 8.495e-06
#  layer #  19       22.0 --  23.0km   1.242e+23molec/cm2  --->         6273   <dod>=1.14e-07   2.672e-10 < dod < 7.587e-06
#  layer #  20       23.0 --  24.0km   1.060e+23molec/cm2  --->         6273   <dod>=9.97e-08   1.999e-10 < dod < 6.824e-06
#  layer #  21       24.0 --  25.0km   9.045e+22molec/cm2  --->         6337   <dod>=8.72e-08   1.496e-10 < dod < 6.083e-06
#  layer #  22       25.0 --  27.5km   1.746e+23molec/cm2  --->         6465   <dod>=1.73e-07   2.362e-10 < dod < 1.233e-05
#  layer #  23       27.5 --  30.0km   1.183e+23molec/cm2  --->         6465   <dod>=1.20e-07   1.119e-10 < dod < 8.841e-06
#  layer #  24       30.0 --  32.5km   7.938e+22molec/cm2  --->         6465   <dod>=8.26e-08   5.216e-11 < dod < 6.139e-06
#  layer #  25       32.5 --  35.0km   5.353e+22molec/cm2  --->         6465   <dod>=5.63e-08   2.399e-11 < dod < 4.157e-06
#  layer #  26       35.0 --  37.5km   3.747e+22molec/cm2  --->         6401   <dod>=3.96e-08   1.194e-11 < dod < 2.859e-06
#  layer #  27       37.5 --  40.0km   2.585e+22molec/cm2  --->         6337   <dod>=2.73e-08   5.812e-12 < dod <  1.92e-06
#  layer #  28       40.0 --  42.5km   1.763e+22molec/cm2  --->         6273   <dod>=1.88e-08   2.746e-12 < dod < 1.288e-06
#  layer #  29       42.5 --  45.0km   1.236e+22molec/cm2  --->         6209   <dod>=1.33e-08    1.38e-12 < dod < 8.879e-07
#  layer #  30       45.0 --  47.5km   8.756e+21molec/cm2  --->         6145   <dod>=9.40e-09   7.015e-13 < dod < 6.113e-07
#  layer #  31       47.5 --  50.0km   6.315e+21molec/cm2  --->         6081   <dod>=6.75e-09   3.651e-13 < dod <  4.31e-07
#  layer #  32       50.0 --  55.0km   8.287e+21molec/cm2  --->         6209   <dod>=8.80e-09    3.29e-13 < dod < 5.727e-07
#  layer #  33       55.0 --  60.0km   4.556e+21molec/cm2  --->         6337   <dod>=4.73e-09   9.596e-14 < dod <  3.22e-07
#  layer #  34       60.0 --  65.0km   2.451e+21molec/cm2  --->         6529   <dod>=2.39e-09   2.566e-14 < dod < 1.735e-07
#  layer #  35       65.0 --  70.0km   1.276e+21molec/cm2  --->         6721   <dod>=1.10e-09   6.119e-15 < dod < 8.583e-08
#  layer #  36       70.0 --  75.0km   6.390e+20molec/cm2  --->         6913   <dod>=4.68e-10   1.287e-15 < dod <  3.87e-08
#  layer #  37       75.0 --  80.0km   3.043e+20molec/cm2  --->         7105   <dod>=1.79e-10   2.362e-16 < dod < 1.555e-08
#  layer #  38       80.0 --  85.0km   1.385e+20molec/cm2  --->         7297   <dod>=5.85e-11   3.516e-17 < dod < 5.355e-09
#    39    85.00km             7297 points    <ac> =   1.6e-16      4.79e-23 < ac <  1.53e-14  @ 16949.761750cm-1
#    40    90.00km             7297 points    <ac> =  4.27e-17      5.32e-24 < ac <  4.14e-15  @ 16949.761750cm-1
#    41    95.00km             7297 points    <ac> =  1.11e-17      5.68e-25 < ac <  1.07e-15  @ 16949.761750cm-1
#    42   100.00km             7169 points    <ac> =   3.3e-18         7e-26 < ac <  3.07e-16  @ 16949.759708cm-1
#    43   105.00km             6913 points    <ac> =  1.16e-18      1.07e-26 < ac <     1e-16  @ 16949.759560cm-1
#    44   110.00km             6465 points    <ac> =  3.86e-19      1.62e-27 < ac <  2.86e-17  @ 16949.760384cm-1
#    45   115.00km             5761 points    <ac> =  1.36e-19      2.95e-28 < ac <  7.78e-18  @ 16949.761224cm-1
#    46   120.00km             5249 points    <ac> =  5.55e-20       7.3e-29 < ac <   2.6e-18  @ 16968.463519cm-1
#
#  INFO --- ac2dod: 47  abs.coefficients with altitudes increasing and pressures decreasing
#  layer #   0        3.0 --   4.0km   1.797e+24molec/cm2  --->         2305   <dod>=2.96e-03   0.0001108 < dod <   0.04022
#  layer #   1        4.0 --   5.0km   1.617e+24molec/cm2  --->         2561   <dod>=1.80e-03   5.992e-05 < dod <   0.02727
#  layer #   2        5.0 --   6.0km   1.452e+24molec/cm2  --->         2753   <dod>=1.06e-03    3.15e-05 < dod <   0.01818
#  layer #   3        6.0 --   7.0km   1.300e+24molec/cm2  --->         3009   <dod>=6.23e-04   1.634e-05 < dod <   0.01192
#  layer #   4        7.0 --   8.0km   1.160e+24molec/cm2  --->         3265   <dod>=3.52e-04   8.147e-06 < dod <  0.007589
#  layer #   5        8.0 --   9.0km   1.032e+24molec/cm2  --->         3521   <dod>=1.79e-04   3.679e-06 < dod <  0.004286
#  layer #   6        9.0 --  10.0km   9.154e+23molec/cm2  --->         3841   <dod>=6.98e-05   1.255e-06 < dod <  0.001865
#  layer #   7       10.0 --  11.0km   8.090e+23molec/cm2  --->         4097   <dod>=2.89e-05   4.528e-07 < dod < 0.0008741
#  layer #   8       11.0 --  12.0km   7.034e+23molec/cm2  --->         4417   <dod>=1.33e-05   1.798e-07 < dod < 0.0004453
#  layer #   9       12.0 --  13.0km   6.013e+23molec/cm2  --->         4673   <dod>=6.14e-06    7.11e-08 < dod < 0.0002288
#  layer #  10       13.0 --  14.0km   5.139e+23molec/cm2  --->         4929   <dod>=2.95e-06   2.923e-08 < dod < 0.0001202
#  layer #  11       14.0 --  15.0km   4.392e+23molec/cm2  --->         5185   <dod>=1.61e-06   1.343e-08 < dod < 7.205e-05
#  layer #  12       15.0 --  16.0km   3.754e+23molec/cm2  --->         5377   <dod>=1.13e-06   8.075e-09 < dod < 5.457e-05
#  layer #  13       16.0 --  17.0km   3.209e+23molec/cm2  --->         5569   <dod>=8.37e-07   5.061e-09 < dod < 4.332e-05
#  layer #  14       17.0 --  18.0km   2.743e+23molec/cm2  --->         5697   <dod>=7.04e-07   3.637e-09 < dod < 3.855e-05
#  layer #  15       18.0 --  19.0km   2.345e+23molec/cm2  --->         5889   <dod>=6.01e-07   2.655e-09 < dod < 3.488e-05
#  layer #  16       19.0 --  20.0km   2.005e+23molec/cm2  --->         6017   <dod>=5.19e-07   1.957e-09 < dod < 3.133e-05
#  layer #  17       20.0 --  21.0km   1.711e+23molec/cm2  --->         6081   <dod>=4.49e-07   1.448e-09 < dod < 2.836e-05
#  layer #  18       21.0 --  22.0km   1.457e+23molec/cm2  --->         6145   <dod>=3.90e-07   1.073e-09 < dod < 2.548e-05
#  layer #  19       22.0 --  23.0km   1.242e+23molec/cm2  --->         6273   <dod>=3.41e-07   8.015e-10 < dod < 2.276e-05
#  layer #  20       23.0 --  24.0km   1.060e+23molec/cm2  --->         6273   <dod>=2.99e-07   5.998e-10 < dod < 2.047e-05
#  layer #  21       24.0 --  25.0km   9.045e+22molec/cm2  --->         6337   <dod>=2.62e-07   4.488e-10 < dod < 1.825e-05
#  layer #  22       25.0 --  27.5km   1.746e+23molec/cm2  --->         6465   <dod>=5.18e-07   7.086e-10 < dod < 3.699e-05
#  layer #  23       27.5 --  30.0km   1.183e+23molec/cm2  --->         6465   <dod>=3.61e-07   3.357e-10 < dod < 2.652e-05
#  layer #  24       30.0 --  32.5km   7.938e+22molec/cm2  --->         6465   <dod>=2.48e-07   1.565e-10 < dod < 1.842e-05
#  layer #  25       32.5 --  35.0km   5.353e+22molec/cm2  --->         6465   <dod>=1.69e-07   7.197e-11 < dod < 1.247e-05
#  layer #  26       35.0 --  37.5km   3.747e+22molec/cm2  --->         6401   <dod>=1.19e-07   3.581e-11 < dod < 8.578e-06
#  layer #  27       37.5 --  40.0km   2.585e+22molec/cm2  --->         6337   <dod>=8.20e-08   1.744e-11 < dod < 5.759e-06
#  layer #  28       40.0 --  42.5km   1.763e+22molec/cm2  --->         6273   <dod>=5.63e-08   8.237e-12 < dod < 3.864e-06
#  layer #  29       42.5 --  45.0km   1.236e+22molec/cm2  --->         6209   <dod>=3.98e-08   4.139e-12 < dod < 2.664e-06
#  layer #  30       45.0 --  47.5km   8.756e+21molec/cm2  --->         6145   <dod>=2.82e-08   2.104e-12 < dod < 1.834e-06
#  layer #  31       47.5 --  50.0km   6.315e+21molec/cm2  --->         6081   <dod>=2.03e-08   1.095e-12 < dod < 1.293e-06
#  layer #  32       50.0 --  55.0km   8.287e+21molec/cm2  --->         6209   <dod>=2.64e-08   9.869e-13 < dod < 1.718e-06
#  layer #  33       55.0 --  60.0km   4.556e+21molec/cm2  --->         6337   <dod>=1.42e-08   2.879e-13 < dod < 9.659e-07
#  layer #  34       60.0 --  65.0km   2.451e+21molec/cm2  --->         6529   <dod>=7.16e-09   7.699e-14 < dod < 5.206e-07
#  layer #  35       65.0 --  70.0km   1.276e+21molec/cm2  --->         6721   <dod>=3.31e-09   1.836e-14 < dod < 2.575e-07
#  layer #  36       70.0 --  75.0km   6.390e+20molec/cm2  --->         6913   <dod>=1.40e-09   3.861e-15 < dod < 1.161e-07
#    38    80.00km             7105 points    <ac> =  7.23e-16      4.99e-22 < ac <  6.56e-14  @ 16949.758660cm-1
#    39    85.00km             7297 points    <ac> =  2.13e-16      6.39e-23 < ac <  2.04e-14  @ 16949.761750cm-1
#    40    90.00km             7297 points    <ac> =   5.7e-17      7.09e-24 < ac <  5.52e-15  @ 16949.761750cm-1
#    41    95.00km             7297 points    <ac> =  1.48e-17      7.57e-25 < ac <  1.42e-15  @ 16949.761750cm-1
#    42   100.00km             7169 points    <ac> =   4.4e-18      9.34e-26 < ac <  4.09e-16  @ 16949.759708cm-1
#    43   105.00km             6913 points    <ac> =  1.55e-18      1.43e-26 < ac <  1.33e-16  @ 16949.759560cm-1
#    44   110.00km             6465 points    <ac> =  5.14e-19      2.16e-27 < ac <  3.81e-17  @ 16949.760384cm-1
#    45   115.00km             5761 points    <ac> =  1.82e-19      3.93e-28 < ac <  1.04e-17  @ 16949.761224cm-1
#    46   120.00km             5249 points    <ac> =   7.4e-20      9.73e-29 < ac <  3.47e-18  @ 16968.463519cm-1
#
#  INFO --- ac2dod: 47  abs.coefficients with altitudes increasing and pressures decreasing
#  layer #   0        3.0 --   4.0km   1.797e+24molec/cm2  --->         2305   <dod>=3.95e-03   0.0001477 < dod <   0.05362
#  layer #   1        4.0 --   5.0km   1.617e+24molec/cm2  --->         2561   <dod>=2.39e-03    7.99e-05 < dod <   0.03636
#  layer #   2        5.0 --   6.0km   1.452e+24molec/cm2  --->         2753   <dod>=1.42e-03     4.2e-05 < dod <   0.02424
#  layer #   3        6.0 --   7.0km   1.300e+24molec/cm2  --->         3009   <dod>=8.30e-04   2.178e-05 < dod <    0.0159
#  layer #   4        7.0 --   8.0km   1.160e+24molec/cm2  --->         3265   <dod>=4.70e-04   1.086e-05 < dod <   0.01012
#  layer #   5        8.0 --   9.0km   1.032e+24molec/cm2  --->         3521   <dod>=2.39e-04   4.905e-06 < dod <  0.005715
#  layer #   6        9.0 --  10.0km   9.154e+23molec/cm2  --->         3841   <dod>=9.30e-05   1.674e-06 < dod <  0.002487
#  layer #   7       10.0 --  11.0km   8.090e+23molec/cm2  --->         4097   <dod>=3.86e-05   6.038e-07 < dod <  0.001165
#  layer #   8       11.0 --  12.0km   7.034e+23molec/cm2  --->         4417   <dod>=1.77e-05   2.398e-07 < dod < 0.0005937
# ...
#  layer #  10       13.0 --  14.0km   5.139e+23molec/cm2  --->         4929   <dod>=7.87e-06   7.796e-08 < dod < 0.0003206
#  layer #  11       14.0 --  15.0km   4.392e+23molec/cm2  --->         5185   <dod>=4.30e-06   3.582e-08 < dod < 0.0001921
#  layer #  12       15.0 --  16.0km   3.754e+23molec/cm2  --->         5377   <dod>=3.02e-06   2.153e-08 < dod < 0.0001455
#  layer #  13       16.0 --  17.0km   3.209e+23molec/cm2  --->         5569   <dod>=2.23e-06    1.35e-08 < dod < 0.0001155
#  layer #  14       17.0 --  18.0km   2.743e+23molec/cm2  --->         5697   <dod>=1.88e-06   9.698e-09 < dod < 0.0001028
#  layer #  15       18.0 --  19.0km   2.345e+23molec/cm2  --->         5889   <dod>=1.60e-06   7.081e-09 < dod < 9.301e-05
#  layer #  16       19.0 --  20.0km   2.005e+23molec/cm2  --->         6017   <dod>=1.38e-06    5.22e-09 < dod < 8.356e-05
#  layer #  17       20.0 --  21.0km   1.711e+23molec/cm2  --->         6081   <dod>=1.20e-06   3.861e-09 < dod < 7.562e-05
#  layer #  18       21.0 --  22.0km   1.457e+23molec/cm2  --->         6145   <dod>=1.04e-06   2.861e-09 < dod < 6.796e-05
#  layer #  19       22.0 --  23.0km   1.242e+23molec/cm2  --->         6273   <dod>=9.11e-07   2.137e-09 < dod <  6.07e-05
#  layer #  20       23.0 --  24.0km   1.060e+23molec/cm2  --->         6273   <dod>=7.97e-07   1.599e-09 < dod < 5.459e-05
#  layer #  21       24.0 --  25.0km   9.045e+22molec/cm2  --->         6337   <dod>=6.98e-07   1.197e-09 < dod < 4.866e-05
#  layer #  22       25.0 --  27.5km   1.746e+23molec/cm2  --->         6465   <dod>=1.38e-06    1.89e-09 < dod < 9.864e-05
#  layer #  23       27.5 --  30.0km   1.183e+23molec/cm2  --->         6465   <dod>=9.63e-07   8.952e-10 < dod < 7.073e-05
#  layer #  24       30.0 --  32.5km   7.938e+22molec/cm2  --->         6465   <dod>=6.61e-07   4.173e-10 < dod < 4.911e-05
#  layer #  25       32.5 --  35.0km   5.353e+22molec/cm2  --->         6465   <dod>=4.51e-07   1.919e-10 < dod < 3.326e-05
#  layer #  26       35.0 --  37.5km   3.747e+22molec/cm2  --->         6401   <dod>=3.16e-07   9.549e-11 < dod < 2.287e-05
#  layer #  27       37.5 --  40.0km   2.585e+22molec/cm2  --->         6337   <dod>=2.19e-07    4.65e-11 < dod < 1.536e-05
#  layer #  28       40.0 --  42.5km   1.763e+22molec/cm2  --->         6273   <dod>=1.50e-07   2.197e-11 < dod <  1.03e-05
#  layer #  29       42.5 --  45.0km   1.236e+22molec/cm2  --->         6209   <dod>=1.06e-07   1.104e-11 < dod < 7.103e-06
#  layer #  30       45.0 --  47.5km   8.756e+21molec/cm2  --->         6145   <dod>=7.52e-08   5.612e-12 < dod <  4.89e-06
#  layer #  31       47.5 --  50.0km   6.315e+21molec/cm2  --->         6081   <dod>=5.40e-08   2.921e-12 < dod < 3.448e-06
#  layer #  32       50.0 --  55.0km   8.287e+21molec/cm2  --->         6209   <dod>=7.04e-08   2.632e-12 < dod < 4.582e-06
#  layer #  33       55.0 --  60.0km   4.556e+21molec/cm2  --->         6337   <dod>=3.79e-08   7.677e-13 < dod < 2.576e-06
#  layer #  34       60.0 --  65.0km   2.451e+21molec/cm2  --->         6529   <dod>=1.91e-08   2.053e-13 < dod < 1.388e-06
#  layer #  35       65.0 --  70.0km   1.276e+21molec/cm2  --->         6721   <dod>=8.83e-09   4.895e-14 < dod < 6.867e-07
#  layer #  36       70.0 --  75.0km   6.390e+20molec/cm2  --->         6913   <dod>=3.74e-09    1.03e-14 < dod < 3.096e-07
#  layer #  37       75.0 --  80.0km   3.043e+20molec/cm2  --->         7105   <dod>=1.43e-09    1.89e-15 < dod < 1.244e-07
#  layer #  38       80.0 --  85.0km   1.385e+20molec/cm2  --->         7297   <dod>=4.68e-10   2.813e-16 < dod < 4.284e-08
#  layer #  39       85.0 --  90.0km   6.058e+19molec/cm2  --->         7297   <dod>=1.35e-10   3.549e-17 < dod < 1.295e-08
#  layer #  40       90.0 --  95.0km   2.513e+19molec/cm2  --->         7297   <dod>=3.59e-11   3.923e-18 < dod < 3.468e-09
#  layer #  41       95.0 -- 100.0km   1.027e+19molec/cm2  --->         7297   <dod>=9.59e-12   4.253e-19 < dod < 9.124e-10
#  layer #  42      100.0 -- 105.0km   4.227e+18molec/cm2  --->         7169   <dod>=2.97e-12   5.392e-20 < dod < 2.711e-10
#  layer #  43      105.0 -- 110.0km   1.793e+18molec/cm2  --->         6913   <dod>=1.03e-12   8.243e-21 < dod < 8.567e-11
#  layer #  44      110.0 -- 115.0km   7.777e+17molec/cm2  --->         6465   <dod>=3.48e-13   1.276e-21 < dod < 2.421e-11
#  layer #  45      115.0 -- 120.0km   3.698e+17molec/cm2  --->         5761   <dod>=1.28e-13   2.458e-22 < dod < 6.873e-12
#   46 layers:                         1.493e+25molec/cm2
#  Atmos1d: got p, T, air   and 7 molecules on 50 levels
#  WARNING --- atmTruncate:  zBoA very small, assuming kilometer units
#
#  INFO --- xs2ac:  atmosphere with  47  levels with  7  molecules  H2O CO2 O3 N2O CO CH4 O2       but  6  of 7  gases without cross sections!
#
#  INFO --- xs2ac:  wavenumber limits identical for all xs:   16946.28029147602 <= v <= 16975.04668137837
#     0     3.00km             2113 points    <ac> =  1.22e-07      4.76e-09 < ac <  1.59e-06  @ 16949.739886cm-1
#     1     4.00km             2305 points    <ac> =  7.54e-08      2.62e-09 < ac <   1.1e-06  @ 16949.751236cm-1
#     2     5.00km             2561 points    <ac> =  4.44e-08      1.37e-09 < ac <  7.23e-07  @ 16949.752485cm-1
#     3     6.00km             2753 points    <ac> =  2.66e-08      7.29e-10 < ac <  4.89e-07  @ 16949.750655cm-1
#     4     7.00km             3009 points    <ac> =  1.49e-08       3.6e-10 < ac <  3.07e-07  @ 16949.751767cm-1
#     5     8.00km             3265 points    <ac> =  8.61e-09      1.83e-10 < ac <     2e-07  @ 16949.752705cm-1
#     6     9.00km             3521 points    <ac> =  3.33e-09      6.21e-11 < ac <  8.67e-08  @ 16949.753506cm-1
#     7    10.00km             3841 points    <ac> =  1.32e-09      2.15e-11 < ac <  3.85e-08  @ 16949.756230cm-1
#     8    11.00km             4097 points    <ac> =  6.08e-10      8.64e-12 < ac <  1.99e-08  @ 16949.756698cm-1
#     9    12.00km             4417 points    <ac> =  2.75e-10      3.34e-12 < ac <  9.93e-09  @ 16949.752322cm-1
#    10    13.00km             4673 points    <ac> =  1.34e-10      1.39e-12 < ac <  5.32e-09  @ 16949.759104cm-1
#    11    14.00km             4929 points    <ac> =  6.25e-11      5.54e-13 < ac <   2.7e-09  @ 16949.759344cm-1
#    38    80.00km             7105 points    <ac> =  1.81e-15      1.25e-21 < ac <  1.64e-13  @ 16949.758660cm-1
#    39    85.00km             7297 points    <ac> =  5.32e-16       1.6e-22 < ac <   5.1e-14  @ 16949.761750cm-1
#    40    90.00km             7297 points    <ac> =  1.42e-16      1.77e-23 < ac <  1.38e-14  @ 16949.761750cm-1
#    41    95.00km             7297 points    <ac> =   3.7e-17      1.89e-24 < ac <  3.55e-15  @ 16949.761750cm-1
#    42   100.00km             7169 points    <ac> =   1.1e-17      2.33e-25 < ac <  1.02e-15  @ 16949.759708cm-1
#    43   105.00km             6913 points    <ac> =  3.86e-18      3.58e-26 < ac <  3.34e-16  @ 16949.759560cm-1
#    44   110.00km             6465 points    <ac> =  1.29e-18       5.4e-27 < ac <  9.52e-17  @ 16949.760384cm-1
#    45   115.00km             5761 points    <ac> =  4.54e-19      9.83e-28 < ac <  2.59e-17  @ 16949.761224cm-1
#    46   120.00km             5249 points    <ac> =  1.85e-19      2.43e-28 < ac <  8.68e-18  @ 16968.463519cm-1
#
#  INFO --- ac2dod: 47  abs.coefficients with altitudes increasing and pressures decreasing
#  layer #   0        3.0 --   4.0km   1.797e+24molec/cm2  --->         2305   <dod>=9.87e-03   0.0003692 < dod <    0.1341
#  layer #   1        4.0 --   5.0km   1.617e+24molec/cm2  --->         2561   <dod>=5.99e-03   0.0001997 < dod <   0.09091
#  layer #   2        5.0 --   6.0km   1.452e+24molec/cm2  --->         2753   <dod>=3.55e-03    0.000105 < dod <   0.06061
#  layer #   3        6.0 --   7.0km   1.300e+24molec/cm2  --->         3009   <dod>=2.08e-03   5.445e-05 < dod <   0.03974
#  layer #   4        7.0 --   8.0km   1.160e+24molec/cm2  --->         3265   <dod>=1.17e-03   2.716e-05 < dod <    0.0253
#  layer #   5        8.0 --   9.0km   1.032e+24molec/cm2  --->         3521   <dod>=5.97e-04   1.226e-05 < dod <   0.01429
#  layer #   6        9.0 --  10.0km   9.154e+23molec/cm2  --->         3841   <dod>=2.33e-04   4.184e-06 < dod <  0.006218
#  layer #   7       10.0 --  11.0km   8.090e+23molec/cm2  --->         4097   <dod>=9.65e-05   1.509e-06 < dod <  0.002914
#  layer #   8       11.0 --  12.0km   7.034e+23molec/cm2  --->         4417   <dod>=4.42e-05   5.994e-07 < dod <  0.001484
#  layer #   9       12.0 --  13.0km   6.013e+23molec/cm2  --->         4673   <dod>=2.05e-05    2.37e-07 < dod < 0.0007626
#  layer #  10       13.0 --  14.0km   5.139e+23molec/cm2  --->         4929   <dod>=9.84e-06   9.745e-08 < dod < 0.0004008
#  layer #  11       14.0 --  15.0km   4.392e+23molec/cm2  --->         5185   <dod>=5.38e-06   4.478e-08 < dod < 0.0002402
#  layer #  12       15.0 --  16.0km   3.754e+23molec/cm2  --->         5377   <dod>=3.77e-06   2.692e-08 < dod < 0.0001819
#  layer #  13       16.0 --  17.0km   3.209e+23molec/cm2  --->         5569   <dod>=2.79e-06   1.687e-08 < dod < 0.0001444
#  layer #  14       17.0 --  18.0km   2.743e+23molec/cm2  --->         5697   <dod>=2.35e-06   1.212e-08 < dod < 0.0001285
#  layer #  15       18.0 --  19.0km   2.345e+23molec/cm2  --->         5889   <dod>=2.00e-06   8.852e-09 < dod < 0.0001163
#  layer #  16       19.0 --  20.0km   2.005e+23molec/cm2  --->         6017   <dod>=1.73e-06   6.525e-09 < dod < 0.0001044
#  layer #  17       20.0 --  21.0km   1.711e+23molec/cm2  --->         6081   <dod>=1.50e-06   4.826e-09 < dod < 9.452e-05
#  layer #  18       21.0 --  22.0km   1.457e+23molec/cm2  --->         6145   <dod>=1.30e-06   3.577e-09 < dod < 8.495e-05
#  layer #  19       22.0 --  23.0km   1.242e+23molec/cm2  --->         6273   <dod>=1.14e-06   2.672e-09 < dod < 7.587e-05
#  layer #  20       23.0 --  24.0km   1.060e+23molec/cm2  --->         6273   <dod>=9.97e-07   1.999e-09 < dod < 6.824e-05
#  layer #  21       24.0 --  25.0km   9.045e+22molec/cm2  --->         6337   <dod>=8.72e-07   1.496e-09 < dod < 6.083e-05
#  layer #  22       25.0 --  27.5km   1.746e+23molec/cm2  --->         6465   <dod>=1.73e-06   2.362e-09 < dod < 0.0001233
#  layer #  23       27.5 --  30.0km   1.183e+23molec/cm2  --->         6465   <dod>=1.20e-06   1.119e-09 < dod < 8.841e-05
#  layer #  24       30.0 --  32.5km   7.938e+22molec/cm2  --->         6465   <dod>=8.26e-07   5.216e-10 < dod < 6.139e-05
#  layer #  25       32.5 --  35.0km   5.353e+22molec/cm2  --->         6465   <dod>=5.63e-07   2.399e-10 < dod < 4.157e-05
#  layer #  26       35.0 --  37.5km   3.747e+22molec/cm2  --->         6401   <dod>=3.96e-07   1.194e-10 < dod < 2.859e-05
#  layer #  27       37.5 --  40.0km   2.585e+22molec/cm2  --->         6337   <dod>=2.73e-07   5.812e-11 < dod <  1.92e-05
#  layer #  28       40.0 --  42.5km   1.763e+22molec/cm2  --->         6273   <dod>=1.88e-07   2.746e-11 < dod < 1.288e-05
#  layer #  29       42.5 --  45.0km   1.236e+22molec/cm2  --->         6209   <dod>=1.33e-07    1.38e-11 < dod < 8.879e-06
#  layer #  30       45.0 --  47.5km   8.756e+21molec/cm2  --->         6145   <dod>=9.40e-08   7.015e-12 < dod < 6.113e-06
#  layer #  31       47.5 --  50.0km   6.315e+21molec/cm2  --->         6081   <dod>=6.75e-08   3.651e-12 < dod <  4.31e-06
#  layer #  32       50.0 --  55.0km   8.287e+21molec/cm2  --->         6209   <dod>=8.80e-08    3.29e-12 < dod < 5.727e-06
#  layer #  33       55.0 --  60.0km   4.556e+21molec/cm2  --->         6337   <dod>=4.73e-08   9.596e-13 < dod <  3.22e-06
#  layer #  34       60.0 --  65.0km   2.451e+21molec/cm2  --->         6529   <dod>=2.39e-08   2.566e-13 < dod < 1.735e-06
#  layer #  35       65.0 --  70.0km   1.276e+21molec/cm2  --->         6721   <dod>=1.10e-08   6.119e-14 < dod < 8.583e-07
#  layer #  36       70.0 --  75.0km   6.390e+20molec/cm2  --->         6913   <dod>=4.68e-09   1.287e-14 < dod <  3.87e-07
#  layer #  37       75.0 --  80.0km   3.043e+20molec/cm2  --->         7105   <dod>=1.79e-09   2.362e-15 < dod < 1.555e-07
#  layer #  38       80.0 --  85.0km   1.385e+20molec/cm2  --->         7297   <dod>=5.85e-10   3.516e-16 < dod < 5.355e-08
#  layer #  39       85.0 --  90.0km   6.058e+19molec/cm2  --->         7297   <dod>=1.69e-10   4.436e-17 < dod < 1.619e-08
#  layer #  40       90.0 --  95.0km   2.513e+19molec/cm2  --->         7297   <dod>=4.48e-11   4.903e-18 < dod < 4.335e-09
#  layer #  41       95.0 -- 100.0km   1.027e+19molec/cm2  --->         7297   <dod>=1.20e-11   5.316e-19 < dod <  1.14e-09
#  layer #  42      100.0 -- 105.0km   4.227e+18molec/cm2  --->         7169   <dod>=3.72e-12   6.739e-20 < dod < 3.389e-10
#  layer #  43      105.0 -- 110.0km   1.793e+18molec/cm2  --->         6913   <dod>=1.29e-12    1.03e-20 < dod < 1.071e-10
#  layer #  44      110.0 -- 115.0km   7.777e+17molec/cm2  --->         6465   <dod>=4.35e-13   1.595e-21 < dod < 3.027e-11
#  layer #  45      115.0 -- 120.0km   3.698e+17molec/cm2  --->         5761   <dod>=1.60e-13   3.072e-22 < dod < 8.591e-12
#   46 layers:                         1.493e+25molec/cm2
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from IPython.utils import io

def genTelluricAtlas(argin): 

    wv0,wv1 = argin 
    wn1,wn0 = 1e7/(air2vac(np.array([wv0,wv1]))/10.)
    print(' started: ',wv0,wv1)
    
    with io.capture_output() as captured:
    
        wv0,wv1 = argin 
        wn1,wn0 = 1e7/(air2vac(np.array([wv0,wv1]))/10.)
        print(wv0,wv1)
        print(wn1,wn0)
        
        dictOfLineLists = higstract('./HITRAN/VIS_IR/64e18314.par',(wn0,wn1),molecule = 'main',verbose = False)
        print(dictOfLineLists.keys())
        
        ## limit the lines to those of some minimum strength
        strMin = 1e-28
        keys = dictOfLineLists.keys()
        keys = [key for key in keys]
        cnt =0
        for mol in keys: 
            wg = dictOfLineLists[mol]['S'] >= strMin
            dictOfLineLists[mol] = dictOfLineLists[mol][wg]
            cnt += len(dictOfLineLists[mol])
            if len(dictOfLineLists[mol]) == 0: 
                dictOfLineLists.pop(mol, None)
        print(' number of lines:',cnt)
        
        
        atm_standard = atmRead('./py4cats/data/atmos/50/USstandard_main.xy',zBoA  = 3) ################## 3 KILOMETERS FOR HALEAKALA - DKIST 
        V = vcd(atm_standard,'H2O')
        h = V /rho/Na * M * 10  ## millimeters
        pwv_standard = h 
        print(h,' millimeters PWV [standard]')
        
        ## get absorption cross sections
        xssDict = lbl2xs(dictOfLineLists, atm_standard['p'], atm_standard['T'],(wn0,wn1),verbose = False)
        
        #plt.figure()
        
        ## loop over ppwv and airmass 
        for ppwv in (1,2,3,4,5,6,8,10,):
            
            ## changes in precipitable water 
            atm_standard = atmRead('./py4cats/data/atmos/50/USstandard_main.xy',zBoA  = 3) ################## 3 KILOMETERS FOR HALEAKALA - DKIST 
            atm_standard['H2O'] *= ppwv / pwv_standard
            V = vcd(atm_standard,'H2O')
        
            ## absorption coefficients
            absCoList = xs2ac(atm_standard, xssDict) 
            ## Optical depth
            dodList = ac2dod(absCoList,verbose=False)
    
            tod = dod2tod(dodList)  ## total od 
            wvair = vac2air(1e7/tod.grid()*10)
    
            savdir = './telluric_synAtlas/'
            savname = savdir + 'pycats_hitran_'+str(int(np.ceil(wvair.min()))) + '_' + str(int(np.floor(wvair.max()))) + '_wvair.npy'
            #print(savname)
            np.save(savname,wvair) 
            
            ## different airmasses 
            for airmass in 1,1.5,2,3,4,:
                ## change the airmass for a slant geometry 
                for n in range(len(dodList)): 
                    dodList[n] = dodList[n]*airmass  ## airmass    
                tod = dod2tod(dodList)  ## total od 
    
                ## back -correct the list to reapply a scaling
                for n in range(len(dodList)): 
                    dodList[n] = dodList[n]/airmass  ## airmass    
    
                #plt.plot(vac2air(1e7/tod.grid()*10),np.exp(-tod),lw = 1)
        
                ## SAVE THE DATA 
                
                savname = savdir + 'pycats_hitran_'+str(int(np.ceil(wvair.min()))) + '_' + str(int(np.floor(wvair.max()))) + \
                                        '_airmass_' + str(airmass) + '_ppwv_' + str(ppwv) + '.npy'
                #print(savname)
                np.save(savname,np.exp(-tod))

    return wv0,wv1

# %%
#genTelluricAtlas((5850,5900))
#genTelluricAtlas((5900,5950))

# %%
## I want to cover 350 to 5000 nm in 50 nm chunks with 4 nm overlap? 
## I want to cover 350 to 5000 nm in 30 nm chunks with 4 nm overlap?

# %%
wv0s = np.arange(155)*30 + (350-2.)
wv1s = np.arange(155)*30 + (350-2.) + 32
wv0s *= 10.
wv1s *= 10.
print(wv1s[-1])
for n in trange(5): 
    print(wv0s[n],wv1s[n])
# Out:
# 50000.0
#   0%|          | 0/5 [00:00<?, ?it/s]
# 3480.0 3800.0
# 3780.0 4100.0
# 4080.0 4400.0
# 4380.0 4700.0
# 4680.0 5000.0

# %%
#genTelluricAtlas((3480,3800))

# %%
if 1: 
    ncpus = 75
    p     = multiprocessing.Pool(processes=ncpus,maxtasksperchild = 1000)
    arg_array = []
    for n in range(len(wv0s)): 
        arg_array.append((wv0s[n],wv1s[n]))
    
    rs    = p.imap(genTelluricAtlas,arg_array)
    p.close()
    
    from tqdm import tqdm
    nargs = len(arg_array)
    pbar = tqdm(total=nargs,position = 0, leave = True)
    for i,res in enumerate(rs):
        wv0,wv1 = res 
        print(' done: ',wv0,wv1)
# Out:
#  started:  started:  started:  started:  started:
#   0%|                                                                                                                                 | 0/155 [00:00<?, ?it/s]
#  started:  started:  started:  started:  started:  started:  started:  started:    started:  started:   started:  started:       started:  started:   started:   started:   started: 4080.0 started:  started:    started:  started: 3480.0 started:  started:   started:  4380.0 started:   4680.0 started:  started: 3780.05580.0 started:  started:  started:  started:  started:  started: 5280.04980.0 started:  started:  started:   started: 6480.0  started: 5880.0 started: 6780.0 started:   started:  started:     started:  started:  7080.06180.0  started:  started:  started:  started:  started:   started:    started:  started:   started:  started:  started:  started:   started: 7380.0   started: 7680.0 started:  started:  started:  started: 7980.0   started: 8280.0 started:  started:   started:    started:  started:  started:  started:            8880.0  8580.0     9480.0 9180.0  10080.04400.0  10380.0  9780.0     10680.0 3800.010980.0  11580.0   11880.0   11280.04700.0       5000.012180.0  4100.0  13380.0 13080.0   5900.0 14280.013980.014580.013680.012780.012480.05600.05300.015180.014880.0 16080.06800.0 15780.015480.07100.06200.016380.0 16980.0 16680.017280.0
# 17580.017880.0 7400.06500.0 18180.018780.019080.018480.019380.0 19980.0
#  19680.020880.0 20280.021180.020580.0 21780.07700.0 22080.0
# 8000.022380.021480.022680.08300.023280.022980.0
#  8600.023580.0
# 24180.024480.0 23880.0 25380.025080.0
# 25680.024780.0
#
#   9200.0
#  8900.0
#
#  9800.0 9500.0
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/tschad/miniconda3/envs/dkist_telluric_atlas/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_473453/3115041654.py", line 16, in genTelluricAtlas
#     dictOfLineLists = higstract('./HITRAN/VIS_IR/64e18314.par',(wn0,wn1),molecule = 'main',verbose = False)
#   File "/home/tschad/dkist_telluric_atlas/py4cats/lbl/higstract.py", line 430, in higstract
#     check_database_file (lineFile)  # determine database type unambiguously
#   File "/home/tschad/dkist_telluric_atlas/py4cats/lbl/higstract.py", line 277, in check_database_file
#     raise ValueError (repr(lineFile) + ' --- line parameter file invalid, nonexisting, ... ?')
# ValueError: './HITRAN/VIS_IR/64e18314.par' --- line parameter file invalid, nonexisting, ... ?
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 14
#      12 nargs = len(arg_array)
#      13 pbar = tqdm(total=nargs,position = 0, leave = True)
# ---> 14 for i,res in enumerate(rs):
#      15     wv0,wv1 = res
#      16     print(' done: ',wv0,wv1)
#
# File ~/miniconda3/envs/dkist_telluric_atlas/lib/python3.9/multiprocessing/pool.py:870, in IMapIterator.next(self, timeout)
#     868 if success:
#     869     return value
# --> 870 raise value
#
# ValueError: './HITRAN/VIS_IR/64e18314.par' --- line parameter file invalid, nonexisting, ... ?
#  10400.0
# 10700.0
# 10100.0     11000.0  11300.0 11900.0  12200.0
#  11600.0
#  started:
#    started: 12500.0
#    13700.0 13400.0  started:    14600.014300.014900.014000.013100.012800.015200.0 started:
# 15500.016400.016100.0 started: 15800.0
# 16700.0
# 17300.0
# 17000.017600.0
# 17900.018200.0 started:
#  started: 19100.0 started: 18500.0
# 19400.019700.018800.0
# 20300.0 started: 20000.0
#  started: 21200.0
#  started: 20600.021500.0
# 22100.020900.022400.0
#  started:  22700.023000.021800.023600.023300.0  started:
# 24500.024800.023900.024200.0
#
# 25700.025400.0 25100.0 started: 26000.0
#
#  started:
#
#
#
#  started:
#
#
#
#  started:
#
#
#
#
#
#
#   started:
#
#  started:
#
#  started:
#
#   started:
#
#  started:
#
#
#  started:
#
#  started: 25980.0
#
#
#
#
#  started: 26280.0
#
#
#  started:  started:
#
#  started:
# 26580.0
#
#  started:    started: 26880.0 27180.0 started:  started:  started: 27480.0 27780.0 started:  started: 28080.0 started:  started:  started:  started:    started:  started:  started:  started:  started: 28380.0  started: 28680.0 started:  started:  28980.0 started:  started:    started:  29280.0 started:  started:  started:   29580.0 started:   started:   started:   started:  29880.0 started:  started:   started:  started: 30180.030480.0 started:    started: 30780.0 started:  started:  started:     started:  started:   31080.0 started:     started:  started:  started:     started:  31380.031680.0 started:    started:      31980.0    32280.0   32580.032880.0 26300.0    26600.033180.033780.0   33480.0 34080.0 26900.0   34380.0     34680.027200.0     35580.027500.034980.0  35280.027800.0  36180.028100.035880.0   36480.028400.036780.037080.0    37680.0 37380.037980.038580.038880.028700.038280.0 39180.029000.039480.040080.0 29300.039780.040380.0  40680.0
# 29600.040980.041580.041280.0
#   29900.041880.042480.0  42180.042780.0
# 30200.043380.043080.0 43680.043980.030500.030800.044280.0
# 31100.044580.044880.045480.045180.0
# 46080.0 45780.0 31400.0
# 46380.0
# 46680.047280.046980.0
#   31700.047580.032000.0 47880.048180.0
#  32300.0
#   32600.0
#   32900.033200.0
#    33500.034100.0 started:
#   33800.0 started: 34400.0
#   34700.0   started:
#
#  35000.0
#    35900.0   started: 35300.0 35600.0
#  started: 36500.0 36200.0   36800.037100.0
# 37400.0
#   38000.037700.038900.038300.039200.038600.0
# 39500.039800.040400.0
# 40100.040700.0
#
# 41000.041300.041900.0
#
# 41600.0 42800.042200.0
#
# 42500.043100.043700.043400.0
# 44000.044300.0 44600.045200.0
# 44900.045800.0
# 46400.045500.0
# 46100.0
#
# 46700.0
# 47000.047300.047600.0
#
# 47900.0
# 48200.048500.0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 48480.0
#
# 48780.0
#
#
#
#
#
# 49080.0
#
#
#
#
#
# 49380.0
# 49680.0
#
#
#
#
#
#
#      48800.050000.049400.049100.049700.0

# %%
## 1 million resolution wv vector
wv = []
wv.append(3500.)
while wv[-1] < 50000: 
    wv.append( wv[-1] + wv[-1]/1000000)
wv = np.array(wv)

trans_final = np.zeros((len(wv),8,5))

# %%
for pidx,ppwv in enumerate((1,2,3,4,5,6,8,10,)):
    for aidx,airmass in enumerate((1,1.5,2,3,4,)):
        print(pidx,aidx)
        f1 = glob.glob('./telluric_synAtlas/*airmass_' + str(airmass) + '_ppwv_' + str(ppwv) + '.npy')
        f1.sort()

        wvair_all = []
        trans_all = []
        for f in f1:
            wvf = os.path.dirname(f) + os.sep +  os.path.basename(f).split('air')[0] +'wvair.npy'
            wvair = np.load(wvf)
            trans = np.load(f)
            wg = (wvair>(wvair.min()+9.)) *  (wvair<(wvair.max()-9.))
            wvair_all.append(wvair[wg])
            trans_all.append(trans[wg])
        
        wvair_all = np.hstack(wvair_all)
        trans_all = np.hstack(trans_all)

        swv = np.argsort(wvair_all)
        wvair_all = wvair_all[swv]
        trans_all = trans_all[swv]

        tr = np.interp(wv,wvair_all,trans_all)

        trans_final[:,pidx,aidx] = tr
# Out:
# 0 0
# 0 1
# 0 2
# 0 3
# 0 4
# 1 0
# 1 1
# 1 2
# 1 3
# 1 4
# 2 0
# 2 1
# 2 2
# 2 3
# 2 4
# 3 0
# 3 1
# 3 2
# 3 3
# 3 4
# 4 0
# 4 1
# 4 2
# 4 3
# 4 4
# 5 0
# 5 1
# 5 2
# 5 3
# 5 4
# 6 0
# 6 1
# 6 2
# 6 3
# 6 4
# 7 0
# 7 1
# 7 2
# 7 3
# 7 4

# %%
print(wv.nbytes/1024./1024.,trans_final.nbytes/1024./1024.)
wv = wv.astype(np.float32)
trans_final = trans_final.astype(np.float32)
print(wv.nbytes/1024./1024.,trans_final.nbytes/1024./1024.)
# Out:
# 20.28856658935547 811.5426635742188
# 10.144283294677734 405.7713317871094

# %%
np.save('./wvair_final.npy',wv)
np.save('./trans_final.npy',trans_final)

# %%
plt.figure()
wp = (wv > 6302-5) * (wv < 6302 + 5)
#wp = (wv > 8542-5) * (wv < 8542 + 5)
#wp = (wv > 14300-15) * (wv < 14300 + 15)

for pidx,ppwv in enumerate((1,2,3,4,5,6,8,10,)):
    for aidx,airmass in enumerate((1,1.5,2,3,4,)):
        plt.plot(wv[wp],trans_final[wp,pidx,aidx],lw = 0.2)
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from  scipy.io import readsav
idld = readsav('/home/tschad/cnSAT/combined_fts_atlases_2898A_54097A.sav')
ftswv    = np.copy(idld['lambda_angstrom'])  ## nm 
ftsatm   = np.copy(idld['atm_absorption'])
ftscor   = np.copy(idld['corrected_flux'])
ftsobs   = np.copy(idld['observed_flux'])

wg = (ftsatm < 0.02) | (ftscor < 0.02)
ftsatm[wg] = np.nan
ftscor[wg] = np.nan

# %%
wpf = (ftswv > 14300-15) * (ftswv < 14300 + 15)
wpf = (ftswv > 6302-5) * (ftswv < 6302 + 5)

#plt.plot(ftswv[wpf],ftsobs[wpf],'.-',color = 'black',lw = 0.5,markersize=1)
plt.plot(ftswv[wpf],ftscor[wpf],'.-',color = 'green',lw = 0.5,markersize=1)

# %%
# https://mark4sun.jpl.nasa.gov/toon/solar/solar_spectrum.html
dc = np.loadtxt('./solar_merged_20200720_600_33300_000.out',skiprows =3)  ## disk center -- 000
dcwv = vac2air(1e7/dc[:,0]*10)
dcsp = dc[:,1]
dcwv = dcwv[::-1]
dcsp = dcsp[::-1]

# https://mark4sun.jpl.nasa.gov/toon/solar/solar_spectrum.html
di = np.loadtxt('solar_merged_20200720_600_33300_100.out',skiprows =3)  ## disk integrated -- 100
diwv = vac2air(1e7/di[:,0]*10)
disp = di[:,1]
diwv = diwv[::-1]
disp = disp[::-1]

# %%
wpf = (dcwv > 14300-15) * (dcwv < 14300 + 15)
wpf = (dcwv > 6302-5) * (dcwv < 6302 + 5)
#plt.plot(dcwv[wpf],dcsp[wpf],'-',color = 'red',lw = 0.5)

# %%
wpf = (diwv > 14300-15) * (diwv < 14300 + 15)
wpf = (diwv > 6302-5) * (diwv < 6302 + 5)
plt.plot(diwv[wpf],disp[wpf],'-',color = 'magenta',lw = 1.5)
